# %% [markdown]
# <a href="https://colab.research.google.com/github/bhola16/CWRU-dataset/blob/main/Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hellooooooooo")
# Out:
# hellooooooooo

# %% [markdown]
# sample program to sum two numbers in Python

# %%
a = 30
b = 50
c = a + b
print(c)
# Out:
# 80

# %%
import numpy as np
arr = np.array((1,2,3,4))
print(arr)
print(type(arr))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
